# %%
import sys, importlib
print("sys.executable:", sys.executable)
print("pyodbc spec:", importlib.util.find_spec("pyodbc"))
import pyodbc
print("pyodbc OK", pyodbc.version)
# Out:
# sys.executable: c:\GenAIclass\.venv-1\Scripts\python.exe
# pyodbc spec: None
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 print("sys.executable:", sys.executable)
#       3 print("pyodbc spec:", importlib.util.find_spec("pyodbc"))
# ----> 4 import pyodbc
#       5 print("pyodbc OK", pyodbc.version)
#
# ModuleNotFoundError: No module named 'pyodbc'
